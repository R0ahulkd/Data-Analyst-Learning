# %%
import numpy as np

ar = np.array([3,4,1,7,8])
s = np.where(ar == 4)
print(s)
# Out:
# (array([1]),)

# %%
s = np.where(ar == 7)
print(s)
# Out:
# (array([3]),)

# %%
s = np.where(ar % 2 == 0)
print(s)
# Out:
# (array([1, 4]),)

# %%
ar = np.array([3,4,1,7,8])
ss = np.searchsorted(ar, )
